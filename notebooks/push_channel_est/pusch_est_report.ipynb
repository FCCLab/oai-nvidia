# %% [markdown]
# # Using pyAerial for channel estimation on Aerial Data Lake data
# This example shows how to use the pyAerial bindings to run cuPHY GPU accelerated channel estimation for 5G NR PUSCH. 5G NR PUSCH data is read from an example over the air captured PUSCH dataset collected and stored using Aerial Data Lake, and the channel is estimated using pyAerial and cuPHY based on the corresponding PUSCH parameters.
#
# **Note:** This example requires that the clickhouse server is running and that the example data has been stored in the database. Refer to the Aerial Data Lake documentation on how to do this.

# %%
# Check platform.
import platform
if platform.machine() not in ['x86_64', 'aarch64']:
    raise SystemExit("Unsupported platform!")

# %% [markdown]
# ## Imports

# %%
import math
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Connecting to clickhouse on remote server
import clickhouse_connect

# Import the channel estimator and some utilities for converting
# the DMRS fields in the right format from the SCF FAPI format that the dataset follows.
from aerial.phy5g.algorithms import ChannelEstimator
from aerial.util.fapi import dmrs_fapi_to_bit_array

# %% [markdown]
# ## Data
# We use an example dataset which has been captured from a real over the air PUSCH transmission.
# The "fapi" table in the database contains the metadata for each PUSCH transmission and the "fh" table contains all of the samples for that slot.

# %%
# Create the pyAerial (cuPHY) channel estimator.
num_ues = 1
num_rx_ant = 1
channel_estimator = ChannelEstimator(num_rx_ant=num_rx_ant)

# Connect to the local database
client = clickhouse_connect.get_client(host='localhost')

# %% [markdown]
# ## Run channel estimation
# From the PUSCH record we extract the PUSCH DMRS parameters and use the TAI time entry to select the IQ samples for that slot
# Channel estimation is then run using the extracted parameters, and the absolute values of the estimated channels are plotted in the same figure.

# %%
import time
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
from tqdm import tqdm  # Import tqdm for the progress bar

# Initialize PDF file to save all plots
pdf_filename = "channel_estimation_PUSCH.pdf"
with PdfPages(pdf_filename) as pdf:
    pusch_records = client.query_df('select * from fapi order by TsTaiNs desc limit 1000')
    for index, pusch_record in tqdm(pusch_records.iterrows(), total=len(pusch_records), desc="PUSCH", bar_format="{l_bar}{bar} | {n_fmt}/{total_fmt} [{rate_fmt}]"):
        query = f"""select TsTaiNs,fhData from fh where 
                TsTaiNs == {pusch_record.TsTaiNs.timestamp()}
                """
    
        fh = client.query_df(query)
        
        # Make sure that the fronthaul database is complete for the SFN.Slot we've chosen
        if fh.index.size < 1:
            pusch_records = pusch_records.drop(index)
            continue
    
        fh_samp = np.array(fh['fhData'][0], dtype=np.float32)
        rx_slot = np.swapaxes(fh_samp.view(np.complex64).reshape(4, 14, 273*12), 2, 0)
    
        # Extract all the needed parameters from the PUSCH record
        slot = int(pusch_record.Slot)
        rntis = [pusch_record.rnti]
        layers = [pusch_record.nrOfLayers]
        start_prb = pusch_record.rbStart
        num_prbs = pusch_record.rbSize
        start_sym = pusch_record.StartSymbolIndex
        num_symbols = pusch_record.NrOfSymbols
        scids = [int(pusch_record.SCID)]
        data_scids = [pusch_record.dataScramblingId]
        dmrs_scrm_id = pusch_record.ulDmrsScramblingId
        num_dmrs_cdm_grps_no_data = pusch_record.numDmrsCdmGrpsNoData
        dmrs_syms = dmrs_fapi_to_bit_array(int(pusch_record.ulDmrsSymbPos))
        dmrs_ports = [pusch_record.dmrsPorts]
        dmrs_max_len = 1
        dmrs_add_ln_pos = 2
        num_subcarriers = num_prbs * 12
        mcs_tables = [pusch_record.mcsTable]
        mcs_indices = [pusch_record.mcsIndex]
        coderates = [pusch_record.targetCodeRate/10.]
        tb_sizes = [pusch_record.TBSize]
        mod_orders = [pusch_record.qamModOrder]
        tb_input = np.array(pusch_record.pduData)
    
        # Run PyAerial (cuPHY) channel estimation
        ch_est = channel_estimator.estimate(
            rx_slot=rx_slot,
            num_ues=1,  # Assuming num_ues=1, adjust if needed
            layers=layers,            
            scids=scids,
            slot=slot,
            dmrs_ports=dmrs_ports,            
            dmrs_syms=dmrs_syms,
            dmrs_scrm_id=dmrs_scrm_id,
            dmrs_max_len=dmrs_max_len,
            dmrs_add_ln_pos=dmrs_add_ln_pos,
            num_dmrs_cdm_grps_no_data=num_dmrs_cdm_grps_no_data,          
            start_prb=start_prb,
            num_prbs=num_prbs,
            prg_size=1,
            num_ul_streams=1,
            start_sym=start_sym,
            num_symbols=num_symbols
        )

        # Create a new figure for each plot
        fig, axs = plt.subplots()
        fig.suptitle("Channel estimates for SFN.Slot: " + str(pusch_record.SFN) + "." + str(pusch_record.Slot))
        axs.set_title(pusch_record.TsTaiNs)
        
        # Plot channel estimates for each DMRS symbol
        for idx in range(int(sum(dmrs_syms))):
            axs.plot(np.abs(ch_est[0][0, 0, :, idx]), label=f'DMRS Symbol {idx}')
        axs.grid(True)
        axs.legend()  # Add a legend to distinguish DMRS symbols

        pdf.savefig(fig)
        plt.close(fig)  # Close the figure to free memory
        
        fig, axs = plt.subplots(1)
        axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
        axs.set_ylim([0, 133 * 12])
        axs.set_title('Ant ' + str(0))
        axs.set(xlabel='Symbol', ylabel='Resource Element')
        axs.label_outer()
        fig.suptitle('Power in RU Antennas') 
        # Save the current figure to the PDF
        pdf.savefig(fig)
        plt.close(fig)  # Close the figure to free memory
# Out:
# PUSCH:   0%|                                                                                                                                                                                                      | 0/1000 [?it/s]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:   0%|▍                                                                                                                                                                                                 | 2/1000 [ 1.30s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:   1%|█▎                                                                                                                                                                                                | 7/1000 [ 1.28s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:   1%|██▍                                                                                                                                                                                              | 13/1000 [ 1.31s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:   2%|███▍                                                                                                                                                                                             | 18/1000 [ 1.31s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:   3%|████▉                                                                                                                                                                                            | 26/1000 [ 1.31s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:   3%|█████▉                                                                                                                                                                                           | 31/1000 [ 1.30s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:   4%|███████                                                                                                                                                                                          | 37/1000 [ 1.31s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:   4%|████████                                                                                                                                                                                         | 42/1000 [ 1.31s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:   4%|████████▋                                                                                                                                                                                        | 45/1000 [ 1.29s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:   5%|█████████▏                                                                                                                                                                                       | 48/1000 [ 1.29s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:   5%|█████████▌                                                                                                                                                                                       | 50/1000 [ 1.28s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:   5%|██████████▏                                                                                                                                                                                      | 53/1000 [ 1.29s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:   6%|██████████▊                                                                                                                                                                                      | 56/1000 [ 1.29s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:   6%|███████████▎                                                                                                                                                                                     | 59/1000 [ 1.29s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:   6%|███████████▋                                                                                                                                                                                     | 61/1000 [ 1.28s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:   7%|█████████████                                                                                                                                                                                    | 68/1000 [ 2.46s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:   7%|██████████████                                                                                                                                                                                   | 73/1000 [ 1.50s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:   8%|███████████████▌                                                                                                                                                                                 | 81/1000 [ 1.33s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:   9%|████████████████▌                                                                                                                                                                                | 86/1000 [ 1.31s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:   9%|█████████████████▋                                                                                                                                                                               | 92/1000 [ 1.31s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  10%|██████████████████▌                                                                                                                                                                              | 97/1000 [ 1.33s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  10%|███████████████████                                                                                                                                                                              | 99/1000 [ 1.31s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  10%|███████████████████▊                                                                                                                                                                            | 104/1000 [ 1.31s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  11%|████████████████████▊                                                                                                                                                                           | 109/1000 [ 1.31s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  11%|█████████████████████▍                                                                                                                                                                          | 112/1000 [ 1.30s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  12%|███████████████████████                                                                                                                                                                         | 121/1000 [ 1.32s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  12%|███████████████████████▍                                                                                                                                                                        | 123/1000 [ 1.30s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  12%|███████████████████████▉                                                                                                                                                                        | 125/1000 [ 1.28s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  13%|████████████████████████▊                                                                                                                                                                       | 130/1000 [ 1.40s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  15%|███████████████████████████▉                                                                                                                                                                    | 146/1000 [ 1.32s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  15%|████████████████████████████▋                                                                                                                                                                   | 150/1000 [ 1.27s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  16%|█████████████████████████████▌                                                                                                                                                                  | 155/1000 [ 1.30s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  16%|██████████████████████████████▊                                                                                                                                                                 | 161/1000 [ 1.30s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  17%|███████████████████████████████▉                                                                                                                                                                | 167/1000 [ 1.32s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  17%|████████████████████████████████▎                                                                                                                                                               | 169/1000 [ 1.38s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  18%|█████████████████████████████████▌                                                                                                                                                              | 176/1000 [ 1.29s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  18%|███████████████████████████████████▎                                                                                                                                                            | 185/1000 [ 1.26s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  19%|███████████████████████████████████▉                                                                                                                                                            | 188/1000 [ 1.28s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  20%|█████████████████████████████████████▍                                                                                                                                                          | 196/1000 [ 1.31s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  20%|█████████████████████████████████████▊                                                                                                                                                          | 198/1000 [ 1.30s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  20%|██████████████████████████████████████▌                                                                                                                                                         | 202/1000 [ 1.27s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  21%|████████████████████████████████████████                                                                                                                                                        | 210/1000 [ 1.32s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  22%|█████████████████████████████████████████▎                                                                                                                                                      | 216/1000 [ 1.32s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  22%|█████████████████████████████████████████▋                                                                                                                                                      | 218/1000 [ 1.29s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  22%|██████████████████████████████████████████▍                                                                                                                                                     | 222/1000 [ 1.30s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  22%|██████████████████████████████████████████▊                                                                                                                                                     | 224/1000 [ 1.29s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  23%|████████████████████████████████████████████                                                                                                                                                    | 231/1000 [ 1.30s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  24%|█████████████████████████████████████████████▊                                                                                                                                                  | 240/1000 [ 1.27s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  25%|████████████████████████████████████████████████▏                                                                                                                                               | 252/1000 [ 1.30s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  26%|█████████████████████████████████████████████████                                                                                                                                               | 257/1000 [ 1.25s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  26%|██████████████████████████████████████████████████▌                                                                                                                                             | 265/1000 [ 1.26s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  27%|███████████████████████████████████████████████████▊                                                                                                                                            | 271/1000 [ 1.29s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  27%|████████████████████████████████████████████████████▏                                                                                                                                           | 273/1000 [ 1.29s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  28%|█████████████████████████████████████████████████████▎                                                                                                                                          | 279/1000 [ 1.32s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  28%|██████████████████████████████████████████████████████▍                                                                                                                                         | 285/1000 [ 1.31s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  30%|████████████████████████████████████████████████████████▎                                                                                                                                       | 295/1000 [ 1.30s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  30%|█████████████████████████████████████████████████████████▎                                                                                                                                      | 300/1000 [ 1.32s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  31%|██████████████████████████████████████████████████████████▋                                                                                                                                     | 307/1000 [ 1.30s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  31%|███████████████████████████████████████████████████████████▏                                                                                                                                    | 310/1000 [ 1.29s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  31%|███████████████████████████████████████████████████████████▌                                                                                                                                    | 312/1000 [ 1.28s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  32%|█████████████████████████████████████████████████████████████                                                                                                                                   | 320/1000 [ 1.28s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  33%|██████████████████████████████████████████████████████████████▎                                                                                                                                 | 326/1000 [ 1.31s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  33%|██████████████████████████████████████████████████████████████▋                                                                                                                                 | 328/1000 [ 1.29s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  33%|███████████████████████████████████████████████████████████████▊                                                                                                                                | 334/1000 [ 1.31s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  34%|████████████████████████████████████████████████████████████████▏                                                                                                                               | 336/1000 [ 1.30s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  34%|████████████████████████████████████████████████████████████████▉                                                                                                                               | 340/1000 [ 1.31s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  35%|██████████████████████████████████████████████████████████████████▋                                                                                                                             | 349/1000 [ 1.28s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  35%|███████████████████████████████████████████████████████████████████▏                                                                                                                            | 352/1000 [ 1.28s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  35%|███████████████████████████████████████████████████████████████████▌                                                                                                                            | 354/1000 [ 1.27s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  36%|████████████████████████████████████████████████████████████████████▊                                                                                                                           | 360/1000 [ 1.32s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  36%|█████████████████████████████████████████████████████████████████████▏                                                                                                                          | 362/1000 [ 1.30s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  36%|█████████████████████████████████████████████████████████████████████▋                                                                                                                          | 365/1000 [ 1.31s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  37%|██████████████████████████████████████████████████████████████████████▋                                                                                                                         | 370/1000 [ 1.31s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  38%|███████████████████████████████████████████████████████████████████████▋                                                                                                                        | 375/1000 [ 1.29s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  38%|█████████████████████████████████████████████████████████████████████████▏                                                                                                                      | 383/1000 [ 1.29s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  39%|██████████████████████████████████████████████████████████████████████████▋                                                                                                                     | 391/1000 [ 1.31s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  40%|███████████████████████████████████████████████████████████████████████████▊                                                                                                                    | 397/1000 [ 1.32s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  40%|████████████████████████████████████████████████████████████████████████████▏                                                                                                                   | 399/1000 [ 1.29s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  40%|████████████████████████████████████████████████████████████████████████████▌                                                                                                                   | 401/1000 [ 1.27s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  41%|█████████████████████████████████████████████████████████████████████████████▋                                                                                                                  | 407/1000 [ 1.31s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  41%|██████████████████████████████████████████████████████████████████████████████                                                                                                                  | 409/1000 [ 1.29s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  42%|███████████████████████████████████████████████████████████████████████████████▎                                                                                                                | 415/1000 [ 1.31s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  42%|███████████████████████████████████████████████████████████████████████████████▋                                                                                                                | 417/1000 [ 1.30s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  42%|████████████████████████████████████████████████████████████████████████████████▏                                                                                                               | 420/1000 [ 1.30s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  42%|█████████████████████████████████████████████████████████████████████████████████▏                                                                                                              | 425/1000 [ 1.30s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  43%|██████████████████████████████████████████████████████████████████████████████████▏                                                                                                             | 430/1000 [ 1.32s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  44%|███████████████████████████████████████████████████████████████████████████████████▋                                                                                                            | 438/1000 [ 1.26s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  45%|█████████████████████████████████████████████████████████████████████████████████████▏                                                                                                          | 446/1000 [ 1.31s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  45%|█████████████████████████████████████████████████████████████████████████████████████▊                                                                                                          | 449/1000 [ 1.30s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  45%|██████████████████████████████████████████████████████████████████████████████████████▏                                                                                                         | 451/1000 [ 1.29s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  45%|██████████████████████████████████████████████████████████████████████████████████████▋                                                                                                         | 454/1000 [ 1.29s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  46%|███████████████████████████████████████████████████████████████████████████████████████                                                                                                         | 456/1000 [ 1.27s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  46%|████████████████████████████████████████████████████████████████████████████████████████▏                                                                                                       | 462/1000 [ 1.32s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  46%|████████████████████████████████████████████████████████████████████████████████████████▌                                                                                                       | 464/1000 [ 1.30s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  47%|█████████████████████████████████████████████████████████████████████████████████████████▊                                                                                                      | 470/1000 [ 1.30s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  47%|██████████████████████████████████████████████████████████████████████████████████████████▏                                                                                                     | 472/1000 [ 1.28s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  48%|██████████████████████████████████████████████████████████████████████████████████████████▋                                                                                                     | 475/1000 [ 1.30s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  48%|███████████████████████████████████████████████████████████████████████████████████████████▎                                                                                                    | 478/1000 [ 1.30s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  48%|███████████████████████████████████████████████████████████████████████████████████████████▋                                                                                                    | 480/1000 [ 1.27s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  49%|█████████████████████████████████████████████████████████████████████████████████████████████▏                                                                                                  | 488/1000 [ 1.36s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  49%|██████████████████████████████████████████████████████████████████████████████████████████████▏                                                                                                 | 493/1000 [ 1.26s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  50%|███████████████████████████████████████████████████████████████████████████████████████████████▋                                                                                                | 501/1000 [ 1.25s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  51%|████████████████████████████████████████████████████████████████████████████████████████████████▋                                                                                               | 506/1000 [ 1.31s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  51%|█████████████████████████████████████████████████████████████████████████████████████████████████▏                                                                                              | 509/1000 [ 1.30s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  51%|█████████████████████████████████████████████████████████████████████████████████████████████████▌                                                                                              | 511/1000 [ 1.29s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  52%|██████████████████████████████████████████████████████████████████████████████████████████████████▋                                                                                             | 517/1000 [ 1.30s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  52%|███████████████████████████████████████████████████████████████████████████████████████████████████▏                                                                                            | 519/1000 [ 1.29s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  52%|███████████████████████████████████████████████████████████████████████████████████████████████████▋                                                                                            | 522/1000 [ 1.29s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  52%|████████████████████████████████████████████████████████████████████████████████████████████████████▎                                                                                           | 525/1000 [ 1.28s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  53%|████████████████████████████████████████████████████████████████████████████████████████████████████▋                                                                                           | 527/1000 [ 1.29s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  53%|█████████████████████████████████████████████████████████████████████████████████████████████████████▏                                                                                          | 530/1000 [ 1.30s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  53%|█████████████████████████████████████████████████████████████████████████████████████████████████████▊                                                                                          | 533/1000 [ 1.29s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  54%|██████████████████████████████████████████████████████████████████████████████████████████████████████▏                                                                                         | 535/1000 [ 1.28s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  54%|███████████████████████████████████████████████████████████████████████████████████████████████████████▋                                                                                        | 543/1000 [ 1.33s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  55%|████████████████████████████████████████████████████████████████████████████████████████████████████████▎                                                                                       | 546/1000 [ 1.30s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  55%|████████████████████████████████████████████████████████████████████████████████████████████████████████▋                                                                                       | 548/1000 [ 1.29s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  55%|█████████████████████████████████████████████████████████████████████████████████████████████████████████▍                                                                                      | 552/1000 [ 1.26s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  56%|███████████████████████████████████████████████████████████████████████████████████████████████████████████▏                                                                                    | 561/1000 [ 1.32s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  56%|███████████████████████████████████████████████████████████████████████████████████████████████████████████▋                                                                                    | 564/1000 [ 1.31s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  57%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████▎                                                                                  | 572/1000 [ 1.32s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  57%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████▋                                                                                  | 574/1000 [ 1.30s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  58%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                                                                                 | 577/1000 [ 1.31s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  58%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████▊                                                                                 | 580/1000 [ 1.30s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# ...
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  81%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉                                     | 811/1000 [ 1.27s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  82%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                                   | 819/1000 [ 1.25s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  83%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉                                  | 827/1000 [ 1.32s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  83%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                                 | 833/1000 [ 1.33s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  84%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                               | 839/1000 [ 1.32s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  84%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋                               | 841/1000 [ 1.30s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  85%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉                              | 848/1000 [ 1.28s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  85%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋                             | 852/1000 [ 1.30s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  85%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                             | 854/1000 [ 1.30s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  86%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋                            | 857/1000 [ 1.29s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  86%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋                           | 862/1000 [ 1.31s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  87%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                          | 867/1000 [ 1.31s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  88%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                        | 875/1000 [ 1.26s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  88%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋                       | 883/1000 [ 1.30s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  89%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊                      | 889/1000 [ 1.30s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  89%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                     | 891/1000 [ 1.28s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  90%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉                     | 895/1000 [ 1.30s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  91%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                   | 906/1000 [ 1.32s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  91%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                  | 908/1000 [ 1.29s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  91%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                  | 911/1000 [ 1.30s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  91%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                 | 914/1000 [ 1.29s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  92%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉                 | 916/1000 [ 1.29s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  92%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍               | 924/1000 [ 1.32s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  93%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍              | 929/1000 [ 1.26s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  94%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉             | 937/1000 [ 1.29s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  94%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████            | 943/1000 [ 1.31s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  94%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍           | 945/1000 [ 1.29s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  95%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎          | 949/1000 [ 1.29s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  95%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏         | 954/1000 [ 1.30s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  96%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌         | 956/1000 [ 1.29s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  96%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏        | 959/1000 [ 1.29s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  96%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋        | 962/1000 [ 1.29s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  96%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████        | 964/1000 [ 1.29s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  97%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋       | 967/1000 [ 1.30s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  97%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎      | 970/1000 [ 1.30s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  97%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋      | 972/1000 [ 1.29s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  98%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏    | 980/1000 [ 1.37s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  98%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊    | 983/1000 [ 1.33s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  98%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏   | 985/1000 [ 1.31s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH:  99%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋  | 993/1000 [ 1.28s/it]/tmp/ipykernel_1125/1240430455.py:86: RuntimeWarning: divide by zero encountered in log10
#   axs.imshow(10*np.log10(np.abs(rx_slot[:, :, 0]**2)), aspect='auto')
# PUSCH: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████ | 1000/1000 [ 1.34s/it]
